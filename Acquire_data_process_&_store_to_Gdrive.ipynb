# %% [markdown]
# **Acquire data, process, & store to Gdrive**
#
# It is recommended to run this notebook with TPU or L4 GPU - MATR HUST RWTH CULCE

# %% [markdown]
# Install dependencies & mount gdrive

# %%
# !git clone https://www.github.com/microsoft/BatteryML
# %cd BatteryML
# !ls
# !pip install -r requirements.txt
# !pip install .
import os
from google.colab import drive

drive.mount('/content/drive')
import os

base_path = '/content/drive/MyDrive/batteryml/datasets/processed'

# Check if the folder exists
if os.path.exists(base_path):
    print("Folder exists.")
else:
    # !mkdir /content/drive/MyDrive/batteryml
    # !mkdir /content/drive/MyDrive/batteryml/datasets
    # !mkdir /content/drive/MyDrive/batteryml/datasets/processed
# Out:
# Cloning into 'BatteryML'...
# ...
# remote: Enumerating objects: 675, done.
# remote: Counting objects: 100% (198/198), done.
# remote: Compressing objects: 100% (150/150), done.
# remote: Total 675 (delta 119), reused 94 (delta 43), pack-reused 477
# Receiving objects: 100% (675/675), 1.33 MiB | 10.61 MiB/s, done.
# Resolving deltas: 100% (432/432), done.
# /content/BatteryML
# baseline.ipynb	bin		    configs	    image    README.md	       SECURITY.md
# batteryml	CODE_OF_CONDUCT.md  dataprepare.md  LICENSE  requirements.txt  setup.py
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 4.1 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117029 sha256=f25fb42020a1532d92381668dd9a2b61f800c5da9bd2ba400acdd99b8ece29f2
# ...

# %% [markdown]
# Enter the datasets you would like to download and process, the list of available datasets can be found in the datasets.md file in the root folder.
#
# The datasets will be added to MyDrive/batteryml/datasets/processed.

# %%
datasets = input('Please enter the datasets you would like to download separated by commas e.g. MATR,RWTH,HUST (Download and save CALCE data in raw/data as per dataprepare.md)').split(',')

for data in datasets:
    # !batteryml download {data} data/raw/{data}
    # !batteryml preprocess {data} data/raw/{data} data/processed/{data}
    # !mkdir /content/drive/MyDrive/batteryml/datasets/processed/{data}
    # !cp -r /content/BatteryML/data/processed/{data} /content/drive/MyDrive/batteryml/datasets/processed/
# Out:
# Please enter the datasets you would like to download separated by commas e.g. MATR,HUSTHUST
# 1.11GB/1.11GB: 100% 1188136932/1188136932 [00:58<00:00, 20178887.94it/s, 16.10MB/s]
# Unzip HUST file our_data/10-8.pkl: 100% 78/78 [00:19<00:00,  3.99it/s]
# Processing HUST cells: 100% 77/77 [04:10<00:00,  3.25s/it]
# Dump batteries to data/processed/HUST: 100% 77/77 [00:15<00:00,  5.07it/s]
# Successfully processed 77 batteries.

# %%
# !batteryml preprocess CALCE /content/drive/MyDrive/batteryml/datasets/raw/CALCE data/processed/CALCE
# !cp -r /content/BatteryML/data/processed/CALCE/ /content/drive/MyDrive/batteryml/datasets/processed
# Out:
# Processing CX2_37 files:   0% 0/13 [00:03<?, ?it/s]
# Load data from files:   0% 0/31 [00:00<?, ?it/s]
# Load data from files:   3% 1/31 [00:03<01:39,  3.31s/it]
# Load data from files:   6% 2/31 [00:03<00:42,  1.45s/it]
# Load data from files:  10% 3/31 [00:03<00:27,  1.01it/s]
# Load data from files:  13% 4/31 [00:06<00:48,  1.79s/it]
# Load data from files:  16% 5/31 [00:09<00:57,  2.19s/it]
# Load data from files:  19% 6/31 [00:12<01:01,  2.45s/it]
# Load data from files:  23% 7/31 [00:13<00:46,  1.95s/it]
# Load data from files:  26% 8/31 [00:16<00:52,  2.27s/it]
# Load data from files:  29% 9/31 [00:19<00:54,  2.46s/it]
# Load data from files:  32% 10/31 [00:22<00:54,  2.60s/it]
# Load data from files:  35% 11/31 [00:23<00:41,  2.06s/it]
# Load data from files:  39% 12/31 [00:26<00:43,  2.29s/it]
# Load data from files:  42% 13/31 [00:28<00:43,  2.40s/it]
# Load data from files:  45% 14/31 [00:30<00:35,  2.08s/it]
# Load data from files:  48% 15/31 [00:32<00:36,  2.27s/it]
# ...

# %%
# !batteryml preprocess HNEI /content/drive/MyDrive/batteryml/datasets/raw/HNEI data/processed/HNEI
# !cp -r /content/BatteryML/data/processed/HNEI/ /content/drive/MyDrive/batteryml/datasets/processed

# %%
# !batteryml preprocess OX /content/drive/MyDrive/batteryml/datasets/raw/OX data/processed/OX
# !cp -r /content/BatteryML/data/processed/OX/ /content/drive/MyDrive/batteryml/datasets/processed
# Out:
# ^C
# cp: cannot stat '/content/BatteryML/data/processed/OX/': No such file or directory

# %%
# !batteryml preprocess SNL /content/drive/MyDrive/batteryml/datasets/raw/SNL data/processed/SNL
# !cp -r /content/BatteryML/data/processed/SNL/ /content/drive/MyDrive/batteryml/datasets/processed

# %%
# !batteryml preprocess UL_PUR /content/drive/MyDrive/batteryml/datasets/raw/UL_PUR data/processed/UL_PUR
# !cp -r /content/BatteryML/data/processed/UL_PUR/ /content/drive/MyDrive/batteryml/datasets/processed
